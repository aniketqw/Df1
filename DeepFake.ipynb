# %%
# !pip install scikit-image
# Out:
# Collecting scikit-image
#   Downloading scikit_image-0.21.0-cp38-cp38-macosx_12_0_arm64.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.21.1 in /opt/anaconda3/envs/Implementation/lib/python3.8/site-packages (from scikit-image) (1.23.5)
# Requirement already satisfied: scipy>=1.8 in /opt/anaconda3/envs/Implementation/lib/python3.8/site-packages (from scikit-image) (1.10.1)
# Requirement already satisfied: networkx>=2.8 in /opt/anaconda3/envs/Implementation/lib/python3.8/site-packages (from scikit-image) (3.1)
# Requirement already satisfied: pillow>=9.0.1 in /opt/anaconda3/envs/Implementation/lib/python3.8/site-packages (from scikit-image) (10.4.0)
# Collecting imageio>=2.27 (from scikit-image)
#   Downloading imageio-2.35.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image)
#   Downloading tifffile-2023.7.10-py3-none-any.whl.metadata (31 kB)
# Collecting PyWavelets>=1.1.1 (from scikit-image)
#   Downloading PyWavelets-1.4.1-cp38-cp38-macosx_11_0_arm64.whl.metadata (1.9 kB)
# Requirement already satisfied: packaging>=21 in /opt/anaconda3/envs/Implementation/lib/python3.8/site-packages (from scikit-image) (24.1)
# Collecting lazy_loader>=0.2 (from scikit-image)
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Downloading scikit_image-0.21.0-cp38-cp38-macosx_12_0_arm64.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 1.0 MB/s eta 0:00:0000:0100:01m
# Downloading imageio-2.35.1-py3-none-any.whl (315 kB)
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading PyWavelets-1.4.1-cp38-cp38-macosx_11_0_arm64.whl (4.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 1.0 MB/s eta 0:00:0000:0100:010m
# Downloading tifffile-2023.7.10-py3-none-any.whl (220 kB)
# Installing collected packages: tifffile, PyWavelets, lazy_loader, imageio, scikit-image
# Successfully installed PyWavelets-1.4.1 imageio-2.35.1 lazy_loader-0.4 scikit-image-0.21.0 tifffile-2023.7.10

# %%
# !pip install torch torchvision matplotlib
# Out:
# Requirement already satisfied: torch in /opt/anaconda3/envs/Implementation/lib/python3.8/site-packages (2.4.0)
# Requirement already satisfied: torchvision in /opt/anaconda3/envs/Implementation/lib/python3.8/site-packages (0.19.0)
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/Implementation/lib/python3.8/site-packages (3.7.5)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/Implementation/lib/python3.8/site-packages (from torch) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/anaconda3/envs/Implementation/lib/python3.8/site-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in /opt/anaconda3/envs/Implementation/lib/python3.8/site-packages (from torch) (1.13.2)
# Requirement already satisfied: networkx in /opt/anaconda3/envs/Implementation/lib/python3.8/site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/Implementation/lib/python3.8/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /opt/anaconda3/envs/Implementation/lib/python3.8/site-packages (from torch) (2024.6.1)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/Implementation/lib/python3.8/site-packages (from torchvision) (1.23.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/anaconda3/envs/Implementation/lib/python3.8/site-packages (from torchvision) (10.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/Implementation/lib/python3.8/site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/Implementation/lib/python3.8/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/Implementation/lib/python3.8/site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/envs/Implementation/lib/python3.8/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/Implementation/lib/python3.8/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/Implementation/lib/python3.8/site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/Implementation/lib/python3.8/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /opt/anaconda3/envs/Implementation/lib/python3.8/site-packages (from matplotlib) (6.4.0)
# Requirement already satisfied: zipp>=3.1.0 in /opt/anaconda3/envs/Implementation/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.17.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/Implementation/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/Implementation/lib/python3.8/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/Implementation/lib/python3.8/site-packages (from sympy->torch) (1.3.0)

# %%
# !pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.3.2-cp38-cp38-macosx_12_0_arm64.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /opt/anaconda3/envs/Implementation/lib/python3.8/site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.5.0 in /opt/anaconda3/envs/Implementation/lib/python3.8/site-packages (from scikit-learn) (1.10.1)
# Collecting joblib>=1.1.1 (from scikit-learn)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.3.2-cp38-cp38-macosx_12_0_arm64.whl (9.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 1.0 MB/s eta 0:00:0000:0100:010m
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.4.2 scikit-learn-1.3.2 threadpoolctl-3.5.0

# %%
# !pip install opencv-python pillow numpy matplotlib
# Out:
# Requirement already satisfied: opencv-python in /opt/anaconda3/envs/Implementation/lib/python3.8/site-packages (4.10.0.84)
# Collecting pillow
#   Downloading pillow-10.4.0-cp38-cp38-macosx_11_0_arm64.whl.metadata (9.2 kB)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/Implementation/lib/python3.8/site-packages (1.23.5)
# Collecting matplotlib
#   Downloading matplotlib-3.7.5-cp38-cp38-macosx_11_0_arm64.whl.metadata (5.7 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.1.1-cp38-cp38-macosx_11_0_arm64.whl.metadata (5.9 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.53.1-cp38-cp38-macosx_11_0_arm64.whl.metadata (162 kB)
# Collecting kiwisolver>=1.0.1 (from matplotlib)
#   Downloading kiwisolver-1.4.5-cp38-cp38-macosx_11_0_arm64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/Implementation/lib/python3.8/site-packages (from matplotlib) (24.1)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.1.4-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/Implementation/lib/python3.8/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /opt/anaconda3/envs/Implementation/lib/python3.8/site-packages (from matplotlib) (6.4.0)
# Requirement already satisfied: zipp>=3.1.0 in /opt/anaconda3/envs/Implementation/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.17.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/Implementation/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading pillow-10.4.0-cp38-cp38-macosx_11_0_arm64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 1.0 MB/s eta 0:00:00a 0:00:01
# Downloading matplotlib-3.7.5-cp38-cp38-macosx_11_0_arm64.whl (7.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 1.0 MB/s eta 0:00:00a 0:00:010m
# Downloading contourpy-1.1.1-cp38-cp38-macosx_11_0_arm64.whl (232 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.53.1-cp38-cp38-macosx_11_0_arm64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 1.0 MB/s eta 0:00:00a 0:00:01
# Downloading kiwisolver-1.4.5-cp38-cp38-macosx_11_0_arm64.whl (66 kB)
# Downloading pyparsing-3.1.4-py3-none-any.whl (104 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.1.1 cycler-0.12.1 fonttools-4.53.1 kiwisolver-1.4.5 matplotlib-3.7.5 pillow-10.4.0 pyparsing-3.1.4

# %%
import os
import cv2
import numpy as np
from PIL import Image, ImageChops, ImageEnhance
import matplotlib.pyplot as plt

def resize_frame(frame, scale_factor=0.5):
    height, width = frame.shape[:2]
    new_size = (int(width * scale_factor), int(height * scale_factor))
    resized_frame = cv2.resize(frame, new_size, interpolation=cv2.INTER_LANCZOS4)
    return resized_frame

def apply_ela(image_path, scale_factor=0.5):
    original = Image.open(image_path)
    original = original.convert("RGB")

    # Resize image
    resized = original.resize((int(original.width * scale_factor), int(original.height * scale_factor)), Image.Resampling.LANCZOS)

    # Convert to numpy arrays
    original_np = np.array(original)
    resized_np = np.array(resized)

    # Calculate error level
    error_level = ImageChops.difference(Image.fromarray(original_np), Image.fromarray(resized_np))

    # Convert error level image to numpy array
    error_level_np = np.array(error_level)

    # Calculate the mean error level value
    mean_error = np.mean(error_level_np)

    return mean_error

def process_videos(video_folder, output_folder):
    # Create the output base directory if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Get all video files in the specified folder
    video_files = [os.path.join(video_folder, f) for f in os.listdir(video_folder) if f.lower().endswith(('.mp4', '.avi', '.mov', '.mkv'))]

    for video_file in video_files:
        # Create a subfolder for each video
        video_name = os.path.splitext(os.path.basename(video_file))[0]
        video_output_folder = os.path.join(output_folder, video_name)
        if not os.path.exists(video_output_folder):
            os.makedirs(video_output_folder)

        cap = cv2.VideoCapture(video_file)

        if not cap.isOpened():
            print(f"Error: Could not open video file {video_file}")
            continue

        frame_number = 0
        mean_errors = []

        while True:
            ret, frame = cap.read()
            if not ret:
                break

            # Resize frame
            resized_frame = resize_frame(frame)

            # Save resized frame
            frame_filename = os.path.join(video_output_folder, f"frame_{frame_number}.png")
            cv2.imwrite(frame_filename, resized_frame)

            # Calculate ELA and get mean error level
            mean_error = apply_ela(frame_filename)
            mean_errors.append(mean_error)

            frame_number += 1

        cap.release()
        print(f"Processing complete for {video_file}")

        # Plotting the mean error levels
        plt.figure(figsize=(10, 5))
        plt.plot(mean_errors, label=f'Error Level - {video_name}')
        plt.xlabel('Frame Number')
        plt.ylabel('Mean Error Level')
        plt.title(f'Mean Error Level Across Frames for {video_name}')
        plt.legend()
        plt.grid(True)
        plt.savefig(os.path.join(video_output_folder, 'error_level_plot.png'))
        plt.close()

# Example usage
video_folder = "train_sample_videos"
output_folder = "output_frames"

process_videos(video_folder, output_folder)
# Out:
# Processing complete for train_sample_videos/cdaxixbosp.mp4
# Processing complete for train_sample_videos/btiysiskpf.mp4
# Processing complete for train_sample_videos/clihsshdkq.mp4
# Processing complete for train_sample_videos/alvgwypubw.mp4
# Processing complete for train_sample_videos/eqvuznuwsa.mp4
# Processing complete for train_sample_videos/eudeqjhdfd.mp4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[69], line 95
#      92 video_folder = "train_sample_videos"
#      93 output_folder = "output_frames"
# ---> 95 process_videos(video_folder, output_folder)
#
# Cell In[69], line 72, in process_videos(video_folder, output_folder)
#      69 cv2.imwrite(frame_filename, resized_frame)
#      71 # Calculate ELA and get mean error level
# ---> 72 mean_error = apply_ela(frame_filename)
#      73 mean_errors.append(mean_error)
#      75 frame_number += 1
#
# Cell In[69], line 18, in apply_ela(image_path, scale_factor)
#      15 original = original.convert("RGB")
#      17 # Resize image
# ---> 18 resized = original.resize((int(original.width * scale_factor), int(original.height * scale_factor)), Image.Resampling.LANCZOS)
#      20 # Convert to numpy arrays
#      21 original_np = np.array(original)
#
# File /opt/anaconda3/envs/Implementation/lib/python3.8/site-packages/PIL/Image.py:2328, in Image.resize(self, size, resample, box, reducing_gap)
#    2316         self = (
#    2317             self.reduce(factor, box=reduce_box)
#    2318             if callable(self.reduce)
#    2319             else Image.reduce(self, factor, box=reduce_box)
#    2320         )
#    2321         box = (
#    2322             (box[0] - reduce_box[0]) / factor_x,
#    2323             (box[1] - reduce_box[1]) / factor_y,
#    2324             (box[2] - reduce_box[0]) / factor_x,
#    2325             (box[3] - reduce_box[1]) / factor_y,
#    2326         )
# -> 2328 return self._new(self.im.resize(size, resample, box))
#
# KeyboardInterrupt:

# %%
import torch
import torchvision.models as models
import torchvision.transforms as transforms
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load the pre-trained ResNet18 model
model = models.resnet18(pretrained=True)

# Remove the final classification layer to get the feature extraction model
model = torch.nn.Sequential(*list(model.children())[:-1])

# Set the model to evaluation mode
model.eval()
# Out:
# /opt/anaconda3/envs/Implementation/lib/python3.8/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/anaconda3/envs/Implementation/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU(inplace=True)
#   (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (5): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (6): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (7): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (8): AdaptiveAvgPool2d(output_size=(1, 1))
# )

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# %%
import os
import torch
import torchvision.models as models
import torchvision.transforms as transforms
from PIL import Image
import numpy as np

# Define image transformation
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Load the pre-trained ResNet18 model
model = models.resnet18(pretrained=True)
model = torch.nn.Sequential(*list(model.children())[:-1])  # Remove the final classification layer
model.eval()

def extract_features(image_path):
    try:
        # Load and transform the image
        image = Image.open(image_path).convert("RGB")
        image_tensor = transform(image).unsqueeze(0)  # Add batch dimension

        print(f"Processing image: {image_path}")
        print(f"Image tensor shape: {image_tensor.shape}")

        # Pass the image through the model
        with torch.no_grad():
            features = model(image_tensor)
            print(f"Extracted features shape: {features.shape}")

        features = features.squeeze().numpy()
        print(f"Squeezed features shape: {features.shape}")
        return features
    except Exception as e:
        print(f"Error processing {image_path}: {e}")
        return None

def process_video_folders(base_folder):
    # Iterate over each folder in the base directory
    for video_folder in os.listdir(base_folder):
        video_folder_path = os.path.join(base_folder, video_folder)
        if not os.path.isdir(video_folder_path):
            continue

        print(f"Processing video folder: {video_folder}")

        # Prepare to store features
        features_list = []

        # Iterate over each file in the video folder
        for file_name in os.listdir(video_folder_path):
            if file_name.startswith("error") and file_name.lower().endswith('.png'):
                ela_image_path = os.path.join(video_folder_path, file_name)

                # Extract features from the ELA image
                features = extract_features(ela_image_path)
                if features is not None and features.size > 0:
                    features_list.append(features)
                else:
                    print(f"Skipped {ela_image_path} due to no features extracted.")

        # Save the features to a numpy file
        features_output_path = os.path.join(video_folder_path, 'features.npy')
        if features_list:
            np.save(features_output_path, np.array(features_list))
            print(f"Features saved for {video_folder}")
        else:
            print(f"No features were extracted for {video_folder}")

# Example usage
base_folder = "output_frames"
process_video_folders(base_folder)
# Out:
# Processing video folder: alvgwypubw
# Processing image: output_frames/alvgwypubw/error_level_plot.png
# Image tensor shape: torch.Size([1, 3, 224, 224])
# Extracted features shape: torch.Size([1, 512, 1, 1])
# Squeezed features shape: (512,)
# Features saved for alvgwypubw
# Processing video folder: eudeqjhdfd
# Processing image: output_frames/eudeqjhdfd/error_level_plot.png
# Image tensor shape: torch.Size([1, 3, 224, 224])
# Extracted features shape: torch.Size([1, 512, 1, 1])
# Squeezed features shape: (512,)
# Features saved for eudeqjhdfd
# Processing video folder: eqvuznuwsa
# Processing image: output_frames/eqvuznuwsa/error_level_plot.png
# Image tensor shape: torch.Size([1, 3, 224, 224])
# Extracted features shape: torch.Size([1, 512, 1, 1])
# Squeezed features shape: (512,)
# Features saved for eqvuznuwsa
# Processing video folder: btiysiskpf
# Processing image: output_frames/btiysiskpf/error_level_plot.png
# Image tensor shape: torch.Size([1, 3, 224, 224])
# Extracted features shape: torch.Size([1, 512, 1, 1])
# Squeezed features shape: (512,)
# Features saved for btiysiskpf
# Processing video folder: cdaxixbosp
# Processing image: output_frames/cdaxixbosp/error_level_plot.png
# Image tensor shape: torch.Size([1, 3, 224, 224])
# Extracted features shape: torch.Size([1, 512, 1, 1])
# Squeezed features shape: (512,)
# Features saved for cdaxixbosp
# Processing video folder: clihsshdkq
# Processing image: output_frames/clihsshdkq/error_level_plot.png
# Image tensor shape: torch.Size([1, 3, 224, 224])
# Extracted features shape: torch.Size([1, 512, 1, 1])
# Squeezed features shape: (512,)
# Features saved for clihsshdkq

# %%
np.load('/Users/aniketsaxena/Documents/p/python/project/deepFakeDetection/df1/organized_frames/real/eudeqjhdfd/features.npy', allow_pickle=True)
# Out:
# array([[1.30054009e+00, 1.75150499e-01, 1.47206461e+00, 1.21956062e+00,
#         7.80197233e-02, 5.38589209e-02, 4.36189264e-01, 4.47781891e-01,
#         1.50521302e+00, 6.22210324e-01, 9.45242960e-03, 2.12246060e+00,
#         5.79149663e-01, 5.79591691e-01, 1.41811058e-01, 1.46813661e-01,
#         5.45903981e-01, 9.11980748e-01, 1.15721858e+00, 4.55431640e-02,
#         3.47043097e-01, 1.53117821e-01, 1.37424842e-01, 1.53564918e+00,
#         6.04817450e-01, 2.34549522e-01, 4.98942971e-01, 5.41440785e-01,
#         1.03637785e-01, 8.10079947e-02, 1.65779912e+00, 9.80842933e-02,
#         1.15696631e-01, 9.21311677e-02, 3.90869111e-01, 1.31433296e+00,
#         6.62818849e-02, 9.76481557e-01, 2.83193398e+00, 2.66995788e-01,
#         8.43623728e-02, 2.04649150e-01, 3.60843353e-02, 3.89950812e-01,
#         5.17459750e-01, 7.21907973e-01, 2.48763800e+00, 0.00000000e+00,
#         6.92498028e-01, 9.26984727e-01, 7.98257113e-01, 3.29818702e+00,
#         4.48163390e-01, 8.52723420e-02, 5.87730050e-01, 3.25417489e-01,
#         5.70606887e-02, 7.84889221e-01, 9.70757782e-01, 1.35865510e-01,
#         7.86255419e-01, 5.78317225e-01, 7.11563289e-01, 6.16557360e-01,
#         1.74499607e+00, 6.80965126e-01, 1.14920521e+00, 6.45769060e-01,
#         1.35991824e+00, 4.50741239e-02, 2.70125240e-01, 2.04485750e+00,
#         7.89856836e-02, 2.78439313e-01, 9.60964620e-01, 2.21930481e-02,
#         7.51383126e-01, 1.07399821e-01, 8.55447292e-01, 1.02237177e+00,
#         5.58905452e-02, 1.81092274e+00, 2.49236494e-01, 1.00409377e+00,
#         5.86068451e-01, 4.53153610e-01, 3.50163206e-02, 2.14491785e-02,
#         3.79632026e-01, 3.11545264e-02, 7.35149905e-02, 3.24389672e+00,
#         3.97955418e-01, 1.77463993e-01, 7.18360960e-01, 6.03500962e-01,
#         4.95499820e-01, 2.93285519e-01, 2.94278175e-01, 2.99540162e-01,
#         1.00539637e+00, 4.05375706e-03, 9.55887698e-03, 9.50909734e-01,
#         1.97156310e+00, 5.66291952e+00, 5.20965271e-03, 6.87974831e-03,
#         5.89472115e-01, 1.62415111e+00, 1.08265899e-01, 2.42838915e-02,
#         2.76902854e-01, 1.57168615e+00, 3.25613260e-01, 5.91467977e-01,
#         2.56723851e-01, 2.14481026e-01, 0.00000000e+00, 2.17908788e-02,
#         2.62021780e+00, 1.37974262e+00, 1.82011668e-02, 6.51778281e-01,
#         1.29390407e+00, 3.64329576e-01, 4.83140945e-01, 1.26328921e+00,
#         2.53556848e+00, 2.41623431e-01, 6.30738167e-03, 6.04370415e-01,
#         2.71191541e-02, 1.48589328e-01, 7.58601546e-01, 1.24634750e-01,
#         2.07294941e+00, 0.00000000e+00, 0.00000000e+00, 2.67584085e-01,
#         5.87598085e-01, 9.87262502e-02, 3.61801624e-01, 3.10837775e-01,
#         6.43237531e-01, 1.54786557e-01, 1.81717128e-01, 7.02335656e-01,
#         4.05290008e-01, 6.24150150e-02, 1.57021475e+00, 6.30961880e-02,
#         1.94321617e-01, 1.59087610e+00, 1.36978090e+00, 8.07967130e-03,
#         5.69066823e-01, 1.19940436e+00, 5.66299856e-01, 2.65799671e-01,
#         1.78193271e+00, 5.29358089e-01, 3.12263787e-01, 1.27047205e+00,
#         2.26886344e+00, 2.45915391e-02, 8.35642517e-01, 2.69403458e-01,
#         1.11478046e-01, 1.39017284e+00, 3.99084568e-01, 6.25210524e-01,
#         1.43701231e+00, 6.30841255e-01, 3.43877935e+00, 2.52777600e+00,
#         2.88814425e-01, 6.52814135e-02, 0.00000000e+00, 1.28873861e+00,
#         4.06538725e-01, 5.49446583e-01, 7.71185458e-02, 2.81480932e+00,
#         5.59356630e-01, 9.83773232e-01, 8.61741453e-02, 4.72946942e-01,
#         1.02095798e-01, 1.25450301e+00, 2.10331202e+00, 4.89427924e-01,
#         3.14725232e+00, 0.00000000e+00, 2.29680181e-01, 5.80215417e-02,
#         1.41801548e+00, 1.55365789e+00, 1.01040328e+00, 2.64857057e-02,
#         4.39419061e-01, 1.11554575e+00, 3.98779333e-01, 4.05093236e-03,
#         9.78807360e-02, 1.10559881e-01, 8.62483442e-01, 4.33935642e-01,
#         3.89507949e-01, 2.54527593e+00, 1.11708987e+00, 9.22361255e-01,
#         9.03873518e-02, 1.84063956e-01, 3.75023365e-01, 1.31988835e+00,
#         9.52019989e-01, 7.86590338e-01, 3.19173217e-01, 1.30125493e-01,
#         5.24070919e-01, 1.33403051e+00, 9.99364816e-03, 6.65175319e-01,
#         4.49919030e-02, 2.01081857e-02, 1.42118841e-01, 1.99640676e-01,
#         3.85552585e-01, 2.55575150e-01, 1.43976614e-01, 7.13157356e-01,
#         3.45264152e-02, 1.11644626e+00, 9.84652936e-01, 1.17313407e-01,
#         1.86623585e+00, 4.55790728e-01, 6.16920650e-01, 7.64470935e-01,
#         6.43243670e-01, 6.49084926e-01, 7.77653605e-02, 1.26195431e+00,
#         8.57414067e-01, 8.87299836e-01, 1.32290184e+00, 7.05288172e-01,
#         8.94559443e-01, 3.04501951e-01, 1.91704899e-01, 3.00039381e-01,
#         7.50435293e-01, 2.80414205e-02, 1.02559078e+00, 1.15041625e+00,
#         5.86074591e-01, 5.51234558e-02, 5.16692042e-01, 3.05808187e-01,
#         5.68237007e-01, 2.40986437e-01, 1.33493459e+00, 1.96237743e-01,
#         2.86962807e-01, 6.05378389e-01, 1.57246757e+00, 8.78319610e-03,
#         9.02242362e-01, 1.24656379e+00, 2.32577696e-01, 3.51397157e-01,
#         5.31221032e-01, 2.56472588e+00, 3.92252088e-01, 2.02381134e-01,
#         7.00563252e-01, 6.39612734e-01, 1.06279969e+00, 7.99241960e-01,
#         1.22250009e+00, 6.50498390e-01, 1.05118036e+00, 1.00484587e-01,
#         1.11072920e-01, 6.64995238e-02, 1.23802751e-01, 3.58934760e-01,
#         1.14767087e+00, 9.19555947e-02, 1.17668498e+00, 2.76395321e-01,
#         1.27004671e+00, 9.80870783e-01, 1.59833574e+00, 1.11702152e-01,
#         7.47369468e-01, 7.29933381e-01, 1.15696096e+00, 1.77958727e+00,
#         2.82259250e+00, 3.20338964e-01, 2.02105522e+00, 7.71639168e-01,
#         1.30728352e+00, 3.31963509e-01, 9.38631892e-02, 7.35169291e-01,
#         1.69217601e-01, 4.57380563e-01, 6.90785229e-01, 1.03724849e+00,
#         3.99732590e-02, 1.97050557e-01, 1.31621861e+00, 8.08198273e-01,
#         1.61742523e-01, 1.02211392e+00, 1.80824077e+00, 9.64300811e-01,
#         2.76504421e+00, 8.67328882e-01, 1.09303474e+00, 4.85662341e-01,
#         2.54517138e-01, 1.80706799e+00, 1.62559867e-01, 2.05902249e-01,
#         1.21813258e-02, 1.47833192e+00, 4.11151409e-01, 1.34604692e-01,
#         1.52119970e+00, 2.59904843e-02, 2.29940510e+00, 7.17723310e-01,
#         1.06864107e+00, 1.67258590e-01, 3.83428067e-01, 7.72576571e-01,
#         5.24829840e-04, 3.79266620e-01, 4.87885177e-01, 1.48087668e+00,
#         3.95841599e-01, 1.23047626e+00, 3.04109156e-01, 9.50406194e-01,
#         5.46095073e-01, 1.17201805e-01, 5.14568508e-01, 2.33434677e+00,
#         4.62003231e-01, 1.07938141e-01, 9.55212831e-01, 6.18816435e-01,
#         2.26313615e+00, 9.32224274e-01, 3.78176644e-02, 1.98502973e-01,
#         3.60315347e+00, 1.99809313e+00, 3.60609126e+00, 9.72379088e-01,
#         1.18012339e-01, 5.24767101e-01, 1.86056507e+00, 6.90815970e-02,
#         1.82356381e+00, 1.11526203e+00, 2.14194879e-01, 1.53569126e+00,
#         2.24398635e-02, 4.54430252e-01, 1.55073225e+00, 5.19405723e-01,
#         2.33500168e-01, 1.90051466e-01, 1.65152505e-01, 2.39742541e+00,
#         4.27441657e-01, 1.98962009e+00, 1.79467928e+00, 1.75038397e+00,
#         9.22489241e-02, 4.91837293e-01, 2.35812902e-01, 5.95715165e-01,
#         2.97019426e-02, 1.54799819e-01, 1.44310403e+00, 8.36869061e-01,
#         9.13677931e-01, 4.40279916e-02, 2.92223901e-01, 8.58177722e-01,
#         8.80153656e-01, 2.53524899e+00, 4.00345612e+00, 5.47147531e-04,
#         9.29875672e-01, 2.09615207e+00, 5.11689901e-01, 1.26889825e+00,
#         3.39222646e+00, 8.40905996e-04, 2.67041624e-01, 5.42814851e-01,
#         6.15951186e-03, 1.51073858e-01, 5.15786052e-01, 3.21863294e+00,
#         5.81576204e+00, 3.41330748e-03, 9.36559588e-02, 2.55836457e-01,
#         8.38190436e-01, 2.76063055e-01, 4.80062634e-01, 8.42656016e-01,
#         0.00000000e+00, 4.35735196e-01, 5.80020845e-01, 2.44790888e+00,
#         1.69332182e+00, 0.00000000e+00, 5.63615739e-01, 7.38949701e-03,
#         3.67744155e-02, 1.99875727e-01, 1.21551670e-01, 1.61091828e+00,
#         1.90247849e-01, 5.31447291e-01, 7.81031072e-01, 6.07599437e-01,
#         4.03901279e-01, 3.57348144e-01, 1.47527325e+00, 8.15608725e-02,
#         1.68702984e+00, 5.13353527e-01, 1.74075112e-01, 6.94077015e-01,
#         2.31826589e-01, 1.11669219e+00, 2.60056127e-02, 0.00000000e+00,
#         9.23631012e-01, 5.60627878e-01, 4.20499849e+00, 5.16289711e-01,
#         2.14510489e+00, 1.34474151e-02, 1.13045192e+00, 1.23686779e+00,
#         1.15486078e-01, 3.33835721e-01, 8.35117936e-01, 1.64442614e-01,
#         5.82127154e-01, 1.21638782e-01, 1.72157693e+00, 4.32603627e-01,
#         1.19511634e-01, 2.23483467e+00, 2.44199538e+00, 2.43591595e+00,
#         1.05672061e+00, 0.00000000e+00, 1.86938886e-02, 3.91726851e-01,
#         6.47945642e-01, 8.27468559e-02, 9.51558650e-02, 1.28240216e+00,
#         9.83302116e-01, 1.99020982e-01, 0.00000000e+00, 1.14011514e+00,
#         6.62450075e-01, 1.57890648e-01, 1.07340229e+00, 3.52510400e-02,
#         1.92241728e+00, 5.76151609e-01, 2.04099607e+00, 1.30981073e-01,
#         4.47561413e-01, 1.48832202e+00, 5.18691063e-01, 1.22588985e-02,
#         9.73827779e-01, 1.63133398e-01, 3.31681222e-01, 9.28073600e-02,
#         4.12162393e-01, 1.20520794e+00, 4.33075130e-02, 1.76614749e+00,
#         4.08404827e-01, 2.20363784e+00, 0.00000000e+00, 8.08442652e-01,
#         2.09643677e-01, 6.52197719e-01, 1.78972393e-01, 6.69838488e-01,
#         6.42968342e-03, 5.49528301e-01, 1.58929490e-02, 2.57235318e-01]],
#       dtype=float32)

# %%
import json
import os
import shutil

# Define paths
input_frames_dir = "output_frames"
output_dir = "organized_frames"
metadata_file = "metadata.json"

# Create output directories
os.makedirs(os.path.join(output_dir, "REAL"), exist_ok=True)
os.makedirs(os.path.join(output_dir, "FAKE"), exist_ok=True)

# Read metadata
with open(metadata_file, "r") as f:
    metadata = json.load(f)

# Process each video
for video, info in metadata.items():
    label = info["label"]
    video_name = os.path.splitext(video)[0]  # Remove the .mp4 extension

    # Source and destination paths
    src_path = os.path.join(input_frames_dir, video_name)
    dst_path = os.path.join(output_dir, label, video_name)

    # Check if the source directory exists
    if os.path.exists(src_path):
        # Copy the frame folder to the appropriate category
        shutil.copytree(src_path, dst_path)
        print(f"Copied {video_name} to {label} category")
    else:
        print(f"Warning: Frame folder for {video_name} not found")

print("Organization complete!")
# Out:
# Warning: Frame folder for aagfhgtpmv not found
# Warning: Frame folder for aapnvogymq not found
# Warning: Frame folder for abarnvbtwb not found
# Warning: Frame folder for abofeumbvv not found
# Warning: Frame folder for abqwwspghj not found
# Warning: Frame folder for acifjvzvpm not found
# Warning: Frame folder for acqfdwsrhi not found
# Warning: Frame folder for acxnxvbsxk not found
# Warning: Frame folder for acxwigylke not found
# Warning: Frame folder for aczrgyricp not found
# Warning: Frame folder for adhsbajydo not found
# Warning: Frame folder for adohikbdaz not found
# Warning: Frame folder for adylbeequz not found
# Warning: Frame folder for aelfnikyqj not found
# Warning: Frame folder for aelzhcnwgf not found
# Warning: Frame folder for aettqgevhz not found
# Warning: Frame folder for aevrfsexku not found
# Warning: Frame folder for afoovlsmtx not found
# Warning: Frame folder for agdkmztvby not found
# Warning: Frame folder for agqphdxmwt not found
# Warning: Frame folder for agrmhtjdlk not found
# Warning: Frame folder for ahbweevwpv not found
# Warning: Frame folder for ahdbuwqxit not found
# Warning: Frame folder for ahfazfbntc not found
# Warning: Frame folder for ahqqqilsxt not found
# Warning: Frame folder for aipfdnwpoo not found
# Warning: Frame folder for ajqslcypsw not found
# Warning: Frame folder for ajwpjhrbcv not found
# Warning: Frame folder for aklqzsddfl not found
# Warning: Frame folder for aknbdpmgua not found
# Warning: Frame folder for aknmpoonls not found
# Warning: Frame folder for akvmwkdyuv not found
# Warning: Frame folder for akxoopqjqz not found
# Warning: Frame folder for akzbnazxtz not found
# Warning: Frame folder for aladcziidp not found
# Warning: Frame folder for alaijyygdv not found
# Warning: Frame folder for alninxcyhg not found
# Warning: Frame folder for altziddtxi not found
# Copied alvgwypubw to FAKE category
# Warning: Frame folder for amaivqofda not found
# Warning: Frame folder for amowujxmzc not found
# Warning: Frame folder for andaxzscny not found
# Warning: Frame folder for aneclqfpbt not found
# Warning: Frame folder for anpuvshzoo not found
# Warning: Frame folder for aorjvbyxhw not found
# Warning: Frame folder for apatcsqejh not found
# Warning: Frame folder for apgjqzkoma not found
# Warning: Frame folder for apogckdfrz not found
# Warning: Frame folder for aqpnvjhuzw not found
# Warning: Frame folder for arkroixhey not found
# Warning: Frame folder for arlmiizoob not found
# Warning: Frame folder for arrhsnjqku not found
# Warning: Frame folder for asaxgevnnp not found
# Warning: Frame folder for asdpeebotb not found
# Warning: Frame folder for aslsvlvpth not found
# Warning: Frame folder for asmpfjfzif not found
# Warning: Frame folder for asvcrfdpnq not found
# Warning: Frame folder for atkdltyyen not found
# Warning: Frame folder for atvmxvwyns not found
# Warning: Frame folder for atxvxouljq not found
# Warning: Frame folder for atyntldecu not found
# Warning: Frame folder for atzdznmder not found
# Warning: Frame folder for aufmsmnoye not found
# Warning: Frame folder for augtsuxpzc not found
# Warning: Frame folder for avfitoutyn not found
# Warning: Frame folder for avgiuextiz not found
# Warning: Frame folder for avibnnhwhp not found
# Warning: Frame folder for avmjormvsx not found
# Warning: Frame folder for avnqydkqjj not found
# Warning: Frame folder for avssvvsdhz not found
# Warning: Frame folder for avtycwsgyb not found
# Warning: Frame folder for avvdgsennp not found
# Warning: Frame folder for avywawptfc not found
# Warning: Frame folder for awhmfnnjih not found
# Warning: Frame folder for awnwkrqibf not found
# Warning: Frame folder for awukslzjra not found
# Warning: Frame folder for axczxisdtb not found
# Warning: Frame folder for axntxmycwd not found
# Warning: Frame folder for axoygtekut not found
# Warning: Frame folder for axwgcsyphv not found
# Warning: Frame folder for axwovszumc not found
# Warning: Frame folder for aybgughjxh not found
# Warning: Frame folder for aybumesmpk not found
# Warning: Frame folder for ayqvfdhslr not found
# Warning: Frame folder for aytzyidmgs not found
# Warning: Frame folder for azpuxunqyo not found
# Warning: Frame folder for azsmewqghg not found
# Warning: Frame folder for bahdpoesir not found
# Warning: Frame folder for bbhpvrmbse not found
# Warning: Frame folder for bbhtdfuqxq not found
# Warning: Frame folder for bbvgxeczei not found
# Warning: Frame folder for bchnbulevv not found
# Warning: Frame folder for bctvsmddgq not found
# Warning: Frame folder for bdbhekrrwo not found
# Warning: Frame folder for bddjdhzfze not found
# Warning: Frame folder for bdgipnyobr not found
# Warning: Frame folder for bdnaqemxmr not found
# Warning: Frame folder for bdxuhamuqx not found
# Warning: Frame folder for beboztfcme not found
# Warning: Frame folder for bejhvclboh not found
# Warning: Frame folder for benmsfzfaz not found
# Warning: Frame folder for beyebyhrph not found
# Warning: Frame folder for bffwsjxghk not found
# Warning: Frame folder for bgaogsjehq not found
# Warning: Frame folder for bggsurpgpr not found
# Warning: Frame folder for bghphrsfxf not found
# Warning: Frame folder for bgmlwsoamc not found
# Warning: Frame folder for bguwlyazau not found
# Warning: Frame folder for bgvhtpzknn not found
# Warning: Frame folder for bgwmmujlmc not found
# Warning: Frame folder for bhaaboftbc not found
# Warning: Frame folder for bhbdugnurr not found
# Warning: Frame folder for bhpwpydzpo not found
# Warning: Frame folder for bhsluedavd not found
# Warning: Frame folder for bilnggbxgu not found
# Warning: Frame folder for bjjbwsqjir not found
# Warning: Frame folder for bjkmjilrxp not found
# Warning: Frame folder for bjsmaqefoi not found
# Warning: Frame folder for bkmdzhfzfh not found
# Warning: Frame folder for bkvetcojbt not found
# Warning: Frame folder for bkwxhglwct not found
# Warning: Frame folder for blpchvmhxx not found
# Warning: Frame folder for blzydqdfem not found
# Warning: Frame folder for bmbbkwmxqj not found
# Warning: Frame folder for bmehkyanbj not found
# Warning: Frame folder for bmhvktyiwp not found
# Warning: Frame folder for bmioepcpsx not found
# Warning: Frame folder for bmjmjmbglm not found
# Warning: Frame folder for bmjzrlszhi not found
# Warning: Frame folder for bnbuonyoje not found
# Warning: Frame folder for bndybcqhfr not found
# Warning: Frame folder for bnjcdrfuov not found
# Warning: Frame folder for bntlodcfeg not found
# Warning: Frame folder for bofqajtwve not found
# Warning: Frame folder for boovltmuwi not found
# Warning: Frame folder for bopqhhalml not found
# Warning: Frame folder for bourlmzsio not found
# Warning: Frame folder for bpapbctoao not found
# Warning: Frame folder for bpwzipqtxf not found
# Warning: Frame folder for bpxckdzddv not found
# Warning: Frame folder for bqdjzqhcft not found
# Warning: Frame folder for bqeiblbxtl not found
# Warning: Frame folder for bqhtpqmmqp not found
# Warning: Frame folder for bqkdbcqjvb not found
# Warning: Frame folder for bqnymlsayl not found
# Warning: Frame folder for bqqpbzjgup not found
# Warning: Frame folder for bqtuuwzdtr not found
# Warning: Frame folder for brhalypwoo not found
# Warning: Frame folder for brvqtabyxj not found
# Warning: Frame folder for brwrlczjvi not found
# Warning: Frame folder for bseamdrpbj not found
# Warning: Frame folder for bsfmwclnqy not found
# Warning: Frame folder for bsqgziaylx not found
# Copied btiysiskpf to FAKE category
# Warning: Frame folder for btjlfpzbdu not found
# Warning: Frame folder for btjwbtsgln not found
# Warning: Frame folder for btmsngnqhv not found
# Warning: Frame folder for btohlidmru not found
# Warning: Frame folder for btugrnoton not found
# Warning: Frame folder for btunxncpjh not found
# Warning: Frame folder for btxlttbpkj not found
# Warning: Frame folder for bulkxhhknf not found
# Warning: Frame folder for bvgwelbeof not found
# Warning: Frame folder for bvzjkezkms not found
# Warning: Frame folder for bweezhfpzp not found
# Warning: Frame folder for bwhlgysghg not found
# Warning: Frame folder for bwipwzzxxu not found
# Warning: Frame folder for bwuwstvsbw not found
# Warning: Frame folder for bxzakyopjf not found
# Warning: Frame folder for bydaidkpdp not found
# Warning: Frame folder for byfenovjnf not found
# Warning: Frame folder for byijojkdba not found
# Warning: Frame folder for byofowlkki not found
# Warning: Frame folder for byqzyxifza not found
# Warning: Frame folder for byunigvnay not found
# Warning: Frame folder for byyqectxqa not found
# Warning: Frame folder for bzmdrafeex not found
# Warning: Frame folder for bzythlfnhq not found
# Warning: Frame folder for caifxvsozs not found
# Warning: Frame folder for caqbrkogkb not found
# Warning: Frame folder for cbbibzcoih not found
# Warning: Frame folder for cbltdtxglo not found
# Warning: Frame folder for ccfoszqabv not found
# Warning: Frame folder for ccmonzqfrz not found
# Copied cdaxixbosp to FAKE category
# Warning: Frame folder for cdbsbdymzd not found
# Warning: Frame folder for cdphtzqrvp not found
# Warning: Frame folder for cdyakrxkia not found
# Warning: Frame folder for cepxysienc not found
# Warning: Frame folder for cettndmvzl not found
# Warning: Frame folder for ceymbecxnj not found
# Warning: Frame folder for cferslmfwh not found
# Warning: Frame folder for cffffbcywc not found
# Warning: Frame folder for cfxkpiweqt not found
# Warning: Frame folder for cfyduhpbps not found
# Warning: Frame folder for cglxirfaey not found
# Warning: Frame folder for cgvrgibpfo not found
# Warning: Frame folder for chtapglbcj not found
# Warning: Frame folder for chviwxsfhg not found
# Warning: Frame folder for chzieimrwu not found
# Warning: Frame folder for ciyoudyhly not found
# Warning: Frame folder for cizlkenljw not found
# Warning: Frame folder for ckbdwedgmc not found
# Warning: Frame folder for ckjaibzfxa not found
# Warning: Frame folder for ckkuyewywx not found
# Warning: Frame folder for cknyxaqouy not found
# Warning: Frame folder for cksanfsjhc not found
# Copied clihsshdkq to FAKE category
# Warning: Frame folder for clrycekyst not found
# Warning: Frame folder for cmbzllswnl not found
# Warning: Frame folder for cmxcfkrjiv not found
# Warning: Frame folder for cnilkgvfei not found
# Warning: Frame folder for coadfnerlk not found
# Warning: Frame folder for cobjrlugvp not found
# Warning: Frame folder for covdcysmbi not found
# Warning: Frame folder for cpjxareypw not found
# Warning: Frame folder for cppdvdejkc not found
# Warning: Frame folder for cprhtltsjp not found
# Warning: Frame folder for cqfugiqupm not found
# Warning: Frame folder for cqhngvpgyi not found
# Warning: Frame folder for cqrskwiqng not found
# Warning: Frame folder for crezycjqyk not found
# Warning: Frame folder for crktehraph not found
# Warning: Frame folder for crzfebnfgb not found
# Warning: Frame folder for cthdnahrkh not found
# Warning: Frame folder for ctpqeykqdp not found
# Warning: Frame folder for cttqtsjvgn not found
# Warning: Frame folder for ctzmavwror not found
# Warning: Frame folder for curpwogllm not found
# Warning: Frame folder for cuzrgrbvil not found
# Warning: Frame folder for cvaksbpssm not found
# Warning: Frame folder for cwbacdwrzo not found
# Warning: Frame folder for cwqlvzefpg not found
# Warning: Frame folder for cwrtyzndpx not found
# Warning: Frame folder for cwsbspfzck not found
# Warning: Frame folder for cwwandrkus not found
# Warning: Frame folder for cxfujlvsuw not found
# Warning: Frame folder for cxrfacemmq not found
# Warning: Frame folder for cxttmymlbn not found
# Warning: Frame folder for cyboodqqyr not found
# Warning: Frame folder for cycacemkmt not found
# Warning: Frame folder for cyclgfjdrv not found
# Warning: Frame folder for cyxlcuyznd not found
# Warning: Frame folder for czfunozvwp not found
# Warning: Frame folder for czkdanyadc not found
# Warning: Frame folder for czmqpxrqoh not found
# Warning: Frame folder for dafhtipaml not found
# Warning: Frame folder for dakiztgtnw not found
# Warning: Frame folder for dakqwktlbi not found
# Warning: Frame folder for dbhoxkblzx not found
# Warning: Frame folder for dbhrpizyeq not found
# Warning: Frame folder for dbnygxtwek not found
# Warning: Frame folder for dboxtiehng not found
# Warning: Frame folder for dbtbbhakdv not found
# Warning: Frame folder for dbzcqmxzaj not found
# Warning: Frame folder for dbzpcjntve not found
# Warning: Frame folder for dcamvmuors not found
# Warning: Frame folder for dcuiiorugd not found
# Warning: Frame folder for ddepeddixj not found
# Warning: Frame folder for ddhfabwpuz not found
# Warning: Frame folder for ddjggcasdw not found
# Warning: Frame folder for ddpvuimigj not found
# Warning: Frame folder for ddqccgmtka not found
# Warning: Frame folder for degpbqvcay not found
# Warning: Frame folder for deywhkarol not found
# Warning: Frame folder for deyyistcrd not found
# Warning: Frame folder for dfbpceeaox not found
# Warning: Frame folder for dgmevclvzy not found
# Warning: Frame folder for dgxrqjdomn not found
# Warning: Frame folder for dgzklxjmix not found
# Warning: Frame folder for dhcndnuwta not found
# Warning: Frame folder for dhcselezer not found
# Warning: Frame folder for dhevettufk not found
# Warning: Frame folder for dhjmzhrcav not found
# Warning: Frame folder for dhkwmjxwrn not found
# Warning: Frame folder for dhoqofwoxa not found
# Warning: Frame folder for dhxctgyoqj not found
# Warning: Frame folder for diomeixhrg not found
# Warning: Frame folder for diopzaywor not found
# Warning: Frame folder for diqraixiov not found
# Warning: Frame folder for diuzrpqjli not found
# Warning: Frame folder for djvtbgwdcc not found
# Warning: Frame folder for djvutyvaio not found
# Warning: Frame folder for djxdyjopjd not found
# Warning: Frame folder for dkdwxmtpuo not found
# Warning: Frame folder for dkhlttuvmx not found
# Warning: Frame folder for dkrvorliqc not found
# Warning: Frame folder for dkuayagnmc not found
# Warning: Frame folder for dkwjwbwgey not found
# Warning: Frame folder for dkzvdrzcnr not found
# Warning: Frame folder for dlpoieqvfb not found
# Warning: Frame folder for dlrsbscitn not found
# Warning: Frame folder for dnexlwbcxq not found
# Warning: Frame folder for dnhvalzvrt not found
# Warning: Frame folder for dntkzzzcdh not found
# Warning: Frame folder for dnyvfblxpm not found
# Warning: Frame folder for doanjploai not found
# Warning: Frame folder for dofusvhnib not found
# Warning: Frame folder for dozyddhild not found
# Warning: Frame folder for dptbnjnkdg not found
# Warning: Frame folder for dptrzdvwpg not found
# Warning: Frame folder for dqnyszdong not found
# Warning: Frame folder for dqppxmoqdl not found
# Warning: Frame folder for dqqtjcryjv not found
# Warning: Frame folder for dqswpjoepo not found
# Warning: Frame folder for dqzreruvje not found
# Warning: Frame folder for drcyabprvt not found
# Warning: Frame folder for drgjzlxzxj not found
# Warning: Frame folder for drsakwyvqv not found
# Warning: Frame folder for drtbksnpol not found
# Warning: Frame folder for dsdoseflas not found
# Warning: Frame folder for dsgpbgsrdm not found
# Warning: Frame folder for dsjbknkujw not found
# Warning: Frame folder for dsndhujjjb not found
# Warning: Frame folder for dtbpmdqvao not found
# Warning: Frame folder for dtocdfbwca not found
# Warning: Frame folder for dubiroskqn not found
# Warning: Frame folder for dulanfulol not found
# Warning: Frame folder for duvyaxbzvp not found
# Warning: Frame folder for duycddgtrl not found
# Warning: Frame folder for duzuusuajr not found
# Warning: Frame folder for dvakowbgbt not found
# Warning: Frame folder for dvumqqhoac not found
# Warning: Frame folder for dwediigjit not found
# Warning: Frame folder for dxbqjxrhin not found
# Warning: Frame folder for dxuliowugt not found
# Warning: Frame folder for dxuplhwvig not found
# Warning: Frame folder for dzieklokdr not found
# Warning: Frame folder for dzqwgqewhu not found
# Warning: Frame folder for dzvyfiarrq not found
# Warning: Frame folder for dzwkmcwkwl not found
# Warning: Frame folder for dzyuwjkjui not found
# Warning: Frame folder for eahlqmfvtj not found
# Warning: Frame folder for eajlrktemq not found
# Warning: Frame folder for ebchwmwayp not found
# Warning: Frame folder for ebebgmtlcu not found
# Warning: Frame folder for ebeknhudxq not found
# Warning: Frame folder for ebkzwjgjhq not found
# Warning: Frame folder for ebywfrmhtd not found
# Warning: Frame folder for eckvhdusax not found
# Warning: Frame folder for ecnihjlfyt not found
# Warning: Frame folder for ecujsjhscd not found
# Warning: Frame folder for ecuvtoltue not found
# Warning: Frame folder for ecwaxgutkc not found
# Warning: Frame folder for eczrseixwq not found
# Warning: Frame folder for edyncaijwx not found
# Warning: Frame folder for eebrkicpry not found
# Warning: Frame folder for eebserckhh not found
# Warning: Frame folder for eejswgycjc not found
# Warning: Frame folder for eekozbeafq not found
# Warning: Frame folder for eepezmygaq not found
# Warning: Frame folder for eeyhxisdfh not found
# Warning: Frame folder for efdyrflcpg not found
# Warning: Frame folder for efwfxwwlbw not found
# Warning: Frame folder for egbbcxcuqy not found
# Warning: Frame folder for eggbjzxnmg not found
# Warning: Frame folder for egghxjjmfg not found
# Warning: Frame folder for ehbnclaukr not found
# Warning: Frame folder for ehccixxzoe not found
# Warning: Frame folder for ehdkmxgtxh not found
# Warning: Frame folder for ehevsxtecd not found
# Warning: Frame folder for ehfiekigla not found
# Warning: Frame folder for ehieahnhte not found
# Warning: Frame folder for ehtdtkmmli not found
# Warning: Frame folder for eiriyukqqy not found
# Warning: Frame folder for eivxffliio not found
# Warning: Frame folder for eiwopxzjfn not found
# Warning: Frame folder for eixwxvxbbn not found
# Warning: Frame folder for ejkqesyvam not found
# Warning: Frame folder for ekcrtigpab not found
# Warning: Frame folder for ekhacizpah not found
# Warning: Frame folder for ekkdjkirzq not found
# Warning: Frame folder for elginszwtk not found
# Warning: Frame folder for ellavthztb not found
# Warning: Frame folder for elvvackpjh not found
# Warning: Frame folder for emaalmsonj not found
# Warning: Frame folder for emfbhytfhc not found
# Warning: Frame folder for emgjphonqb not found
# Warning: Frame folder for ensyyivobf not found
# Warning: Frame folder for eoewqcpbgt not found
# Warning: Frame folder for eprybmbpba not found
# Warning: Frame folder for epymyyiblu not found
# Warning: Frame folder for eqjscdagiv not found
# Warning: Frame folder for eqnoqyfquo not found
# Copied eqvuznuwsa to FAKE category
# Warning: Frame folder for erlvuvjsjf not found
# Warning: Frame folder for erqgqacbqe not found
# Warning: Frame folder for errocgcham not found
# Warning: Frame folder for esckbnkkvb not found
# Warning: Frame folder for esgftaficx not found
# Warning: Frame folder for esnntzzajv not found
# Warning: Frame folder for esxrvsgpvb not found
# Warning: Frame folder for esyhwdfnxs not found
# Warning: Frame folder for esyrimvzsa not found
# Warning: Frame folder for etdcqxabww not found
# Warning: Frame folder for etejaapnxh not found
# Warning: Frame folder for etmcruaihe not found
# Warning: Frame folder for etohcvnzbj not found
# Copied eudeqjhdfd to REAL category
# Warning: Frame folder for eukvucdetx not found
# Organization complete!

# %%
import os
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report
from tqdm import tqdm

# Define paths
data_dir = "organized_frames"
categories = ["fake", "real"]

# Initialize data lists
features = []
labels = []

# Load features and labels
for category in categories:
    category_path = os.path.join(data_dir, category, "")
    label = categories.index(category)
    print(f"Processing {category} videos...")

    for video_folder in tqdm(os.listdir(category_path)):
        video_path = os.path.join(category_path, video_folder)
        features_path = os.path.join(video_path, "features.npy")

        if os.path.exists(features_path):
            video_features = np.load(features_path)
            features.append(video_features)
            labels.append(label)
        else:
            print(f"Warning: features.npy not found in {video_path}")

# Convert lists to numpy arrays
features = np.array(features)
labels = np.array(labels)

# Ensure features and labels are not empty
if len(features) == 0:
    raise ValueError("Features array is empty. Please check the data loading process.")

# Flatten the features if necessary
if len(features.shape) > 2:
    features = features.reshape(features.shape[0], -1)

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

# SVM Model
print("Training SVM model...")
svm_model = SVC(kernel='linear')  # You can experiment with different kernels like 'rbf'
svm_model.fit(X_train, y_train)
y_pred_svm = svm_model.predict(X_test)

# Evaluate SVM
print("SVM Classification Report:")
print(classification_report(y_test, y_pred_svm))
print(f"SVM Accuracy: {accuracy_score(y_test, y_pred_svm):.2f}")

# KNN Model
print("Training KNN model...")
knn_model = KNeighborsClassifier(n_neighbors=3)  # You can adjust the number of neighbors
knn_model.fit(X_train, y_train)
y_pred_knn = knn_model.predict(X_test)

# Evaluate KNN
print("KNN Classification Report:")
print(classification_report(y_test, y_pred_knn))
print(f"KNN Accuracy: {accuracy_score(y_test, y_pred_knn):.2f}")
# Out:
# Processing fake videos...
# 100%|██████████| 5/5 [00:00<00:00, 2555.01it/s]
# Processing real videos...
# 100%|██████████| 1/1 [00:00<00:00, 2289.47it/s]
# Training SVM model...
# SVM Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
# SVM Accuracy: 1.00
# Training KNN model...
# KNN Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
# KNN Accuracy: 1.00
